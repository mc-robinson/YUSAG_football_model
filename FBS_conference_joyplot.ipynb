# %%
install.packages("ggjoy")
install.packages("viridis")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependencies ‘viridisLite’, ‘gridExtra’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(ggjoy)
library(ggplot2)
library(magrittr)
library(dplyr)
library(viridis)
# Out:
# Loading required package: viridisLite

# %%
x <- read.csv("FBS_joyplot_data.csv", as.is = T)

# %%
x
# Out:
#     Team           Conference YUSAG_Coefficient rank
# 1   Alabama        SEC        33.16              1
# 2   Ohio St.       B10        29.25              2
# 3   Clemson        ACC        29.13              3
# 4   Michigan       B10        26.49              4
# 5   Washington     P12        24.61              5
# 6   Oklahoma       B12        23.15              6
# 7   LSU            SEC        21.11              7
# 8   Louisville     ACC        19.12              8
# 9   Florida St     ACC        18.64              9
# 10  USC            P12        17.93             10
# 11  Wisconsin      B10        16.82             11
# 12  Auburn         SEC        16.68             12
# 13  Stanford       P12        15.95             13
# 14  Virginia Tech  ACC        15.48             14
# 15  Florida        SEC        15.18             15
# 16  Washington St  P12        14.88             16
# 17  Miami FL       ACC        14.58             17
# 18  Penn St        B10        13.44             18
# 19  Tennessee      SEC        13.38             19
# 20  Mississippi    SEC        12.70             20
# 21  Texas A&M      SEC        12.54             21
# 22  North Carolina ACC        12.42             22
# 23  WKU            CUSA       11.53             23
# 24  Oklahoma St    B12        11.24             24
# 25  West Virginia  B12        10.82             25
# 26  Colorado       P12        10.69             26
# 27  Houston        AAC        10.48             27
# 28  Notre Dame     FBSI       10.32             28
# 29  Pittsburgh     ACC        10.22             29
# 30  Utah           P12        10.20             30
# ⋮   ⋮              ⋮          ⋮                 ⋮
# 99  Miami OH       MAC        -11.96            101
# 100 UAB            CUSA       -12.11            102
# 101 Bowling Green  MAC        -12.13            103
# 102 Nevada         MWC        -12.13            104
# 103 South Alabama  SBC        -12.65            105
# 104 Connecticut    AAC        -13.11            106
# 105 Akron          MAC        -13.31            107
# 106 Ball St        MAC        -14.04            108
# 107 Purdue         B10        -14.31            109
# 108 Rutgers        B10        -14.83            110
# 109 Marshall       CUSA       -14.88            111
# 110 E Michigan     MAC        -14.93            112
# 111 San Jose St    MWC        -15.25            113
# 112 Hawaii         MWC        -15.79            114
# 113 Georgia St     SBC        -16.18            115
# 114 Kent           MAC        -16.21            116
# 115 UNLV           MWC        -16.46            117
# 116 Massachusetts  FBSI       -17.39            118
# 117 Kansas         B12        -17.40            119
# 118 North Texas    CUSA       -18.10            120
# 119 Florida Intl   CUSA       -19.67            121
# 120 Fresno St      MWC        -19.78            122
# 121 Rice           CUSA       -19.93            123
# 122 FL Atlantic    CUSA       -20.62            124
# 123 Buffalo        MAC        -21.29            125
# 124 ULM            SBC        -22.14            126
# 125 New Mexico St  SBC        -22.42            127
# 126 UTEP           CUSA       -23.13            128
# 127 Charlotte      CUSA       -24.26            129
# 128 Texas St       SBC        -29.87            130

# %%
x %>% mutate(group = reorder(Conference, YUSAG_Coefficient, median)) %>%
  ggplot(aes(x = YUSAG_Coefficient, y = group, fill = ..x..)) + 
  geom_joy_gradient(scale = 3) + theme_joy() +
  scale_y_discrete(expand = c(0.01, 0)) + 
  scale_x_continuous(expand = c(0.01, 0)) +
  theme(legend.position="none") +
  scale_fill_viridis(name = "Group", option = "C") +
  labs(y = "Conference", title = "NCAA FBS Football Power Rankings")
# Out:
# Picking joint bandwidth of 5.06
# plot without title
